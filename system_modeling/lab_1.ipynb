# %% [markdown]
# # Модель по экономике: Простая модель совокупного спроса и предложения (AD-AS)

# %% [markdown]
# ## 1. Описание модели
#
# Модель совокупного спроса и предложения (AD-AS) используется для анализа
# макроэкономических явлений, таких как экономический рост, инфляция и безработица. Она
# описывает взаимодействие между совокупным спросом (AD) и совокупным предложением
# (AS) в экономике.
#
# *Спрос* — это запрос фактического или потенциального покупателя, потребителя на
# приобретение товара по имеющимся у него средствам, которые предназначены для этой
# покупки. Спрос отражает, с одной стороны, потребность покупателя в некоторых товарах
# или услугах, желание приобрести эти товары или услуги в определенном количестве и, с
# другой стороны, возможность оплатить покупку по цене, находящейся в пределах
# «доступного» диапазона.
#
# Вместе с этими обобщёнными определениями спрос характеризуется рядом свойств и
# количественных параметров, из которых, прежде всего, следует выделить объём или
# величину спроса.
#
# С позиций количественного измерения спрос на товар, понимается как объём спроса,
# означает количество данного товара, которое покупатели (потребители) желают, готовы и
# имеют денежную возможность приобрести за некоторый период в определённом ценовом
# диапазоне.
#
# *Величина спроса* — количество товара или услуг определённого вида и качества, которое
# покупатель желает купить по определённой цене за определённый период. Величина спроса
# зависит от доходов покупателей, цен на товары и услуги, цен на товары-субституты и
# комплементарные блага, ожиданий покупателей, их вкусов и предпочтений.
# Закон спроса — величина (объём) спроса уменьшается по мере увеличения цены товара.
# Математически это означает, что между величиной спроса и ценой существует обратная
# зависимость. То есть повышение цены вызывает понижение величины спроса, снижение же
# цены вызывает повышение величины спроса.
#
# Неценовые факторы, влияющие на спрос:
#
# * Уровень доходов в обществе;
# * Размеры рынка;
# * Мода, сезонность;
# * Наличие товаров-субститутов (заменителей);
# * Инфляционные ожидания.
#
# Природа закона спроса не сложная. Если у покупателя есть определенная сумма денег на
# приобретение данного товара, то он сможет купить тем меньше товара, чем больше цена и
# наоборот. Конечно, реальная картина намного сложнее, так как покупатель может
# привлечь дополнительные средства, купить вместо данного товара другой — товарсубститут.
#
# **Закон предложения** — при прочих неизменных факторах величина (объём) предложения
# увеличивается по мере увеличения цены на товар.
#
# Рост величины предложения на товар при увеличении его цены обусловлен в общем случае
# тем обстоятельством, что при неизменных издержках на единицу товара с увеличением
# цены растёт прибыль и производителю (продавцу) становится выгодным продать больше
# товара. Реальная картина на рынке сложнее этой простой схемы, но выраженная в ней
# тенденция имеет место.
#
# Неценовые факторы, влияющие на предложение:
#
# 1. Наличие товаров-заменителей.
# 2. Наличие товаров-комплементов (дополняющих).
# 3. Уровень технологий.
# 4. Объём и доступность ресурсов.
# 5. Налоги и дотации.
# 6. Природные условия.
# 7. Ожидания (инфляционные, социально-политические).
# 8. Размеры рынка.
#
# ---

# %% [markdown]
# ### Основные составляющие модели (AD-AS):
#
# 1. Совокупный спрос (AD): Отражает общий уровень расходов в экономике. Зависит от уровня
# цен (P) и объема выпуска (Y):
#
# $AD = C + I + G + (X - M)$
#
# C: Потребительские расходы.
# I: Инвестиции.
# G: Государственные расходы.
# X - M: Чистый экспорт.
#
# 2. Совокупное предложение (AS): Отражает общий объем выпуска в экономике, который фирмы
# готовы произвести при определенном уровне цен. Зависит от:
# - Потенциального выпуска (Y*),
# - Коэффициента чувствительности предложения к изменению цен (k),
# - Уровня цен (P).
#
# $AS = Y* + k(P - Pe)$
#
# Pe: Ожидаемый уровень цен.
#
# 3. Равновесие: Устанавливается, когда AD = AS.
#
# ---

# %% [markdown]
# ## 4. Программа на языке Python
#
#
# ```python
# def simulate_ad_as(C, I, G, X, M, Y_star, k, P_e, P, dt, T):
#  t = 0 # Начальное время
#  results = [] # Список для хранения результатов
#  print("Time\tPrice Level\tAD\tAS")
#  while t < T:
#  # Вычисление совокупного спроса
#  AD = C + I + G + (X - M)
#  # Вычисление совокупного предложения
#  AS = Y_star + k * (P - P_e)
#  # Корректировка уровня цен
#  if AD > AS:
#  P += 0.01 * (AD - AS) # Рост уровня цен
#  else:
#  P -= 0.01 * (AS - AD) # Снижение уровня цен
#  # Сохранение результатов
#  results.append((t, P, AD, AS))
#  print(f"{t:.2f}\t{P:.2f}\t{AD:.2f}\t{AS:.2f}")
#  # Увеличение времени
#  t += dt
#  return results
# # Инициализация параметров
# C = 100 # Потребительские расходы
# I = 50 # Инвестиции
# G = 70 # Государственные расходы
# X = 30 # Экспорт
# M = 20 # Импорт
# Y_star = 200 # Потенциальный выпуск
# k = 0.5 # Чувствительность предложения
# P_e = 100 # Ожидаемый уровень цен
# P = 100 # Начальный уровень цен
# dt = 0.1 # Шаг времени
# T = 50 # Общее время моделирования
# # Запуск симуляции
# simulate_ad_as(C, I, G, X, M, Y_star, k, P_e, P, dt, T)
#
# ```

# %% [markdown]
# ## 5. Эксперименты с моделью
# ### 1. Базовый эксперимент:
#
# - Параметры: C = 100, I = 50, G = 70, X = 30, M = 20, Y* = 200, k = 0.5, Pe = 100.
# - Цель: Наблюдать изменения уровня цен и динамику спроса и предложения в экономике.
#
# ### 2. Стимулирование спроса:
#
# - Увеличить G до 100 (увеличение государственных расходов).
# - Цель: Исследовать влияние фискальной политики на экономику.
#
# ### 3. Шок предложения:
#
# - Увеличить Pe до 120 (ожидаемое повышение цен).
# - Цель: Понять, как ожидания влияют на равновесие.
#
# ### 4. Снижение инвестиций:
#
# - Уменьшить I до 20.
# - Цель: Исследовать последствия сокращения инвестиций на экономическую стабильность.
#
# ### 5. Увеличение чувствительности предложения (k):
#
# - Изменить k с 0.5 на 1.0.
# - Цель: Понять, как более гибкое предложение влияет на экономику.
#
# Эти эксперименты демонстрируют, как изменения в макроэкономических параметрах
# влияют на динамику спроса, предложения и уровня цен. Модель является полезным
# инструментом для изучения экономических механизмов.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ### Запустим базовую программу

# %%
def simulate_ad_as(C, I, G, X, M, Y_star, k, P_e, P, dt, T):
 t = 0 # Начальное время
 results = [] # Список для хранения результатов
 print("Time\tPrice Level\tAD\tAS")
 while t < T:
    # Вычисление совокупного спроса
    AD = C + I + G + (X - M)
    # Вычисление совокупного предложения
    AS = Y_star + k * (P - P_e)
    
    # Корректировка уровня цен
    if AD > AS:
        P += 0.01 * (AD - AS) # Рост уровня цен
    else:
        P -= 0.01 * (AS - AD) # Снижение уровня цен
        
    # Сохранение результатов
    results.append((t, P, AD, AS))
    print(f"{t:.2f}\t{P:.2f}\t{AD:.2f}\t{AS:.2f}")
    # Увеличение времени
    t += dt
    
 return results


# Инициализация параметров
C = 100 # Потребительские расходы
I = 50 # Инвестиции
G = 70 # Государственные расходы
X = 30 # Экспорт
M = 20 # Импорт
Y_star = 200 # Потенциальный выпуск
k = 0.5 # Чувствительность предложения
P_e = 100 # Ожидаемый уровень цен
P = 100 # Начальный уровень цен
dt = 0.1 # Шаг времени
T = 50 # Общее время моделирования
# Запуск симуляции
simulate_ad_as(C, I, G, X, M, Y_star, k, P_e, P, dt, T)
# Out:
# Time	Price Level	AD	AS
# 0.00	100.30	230.00	200.00
# 0.10	100.60	230.00	200.15
# 0.20	100.90	230.00	200.30
# 0.30	101.19	230.00	200.45
# 0.40	101.49	230.00	200.60
# 0.50	101.78	230.00	200.74
# 0.60	102.07	230.00	200.89
# 0.70	102.36	230.00	201.03
# 0.80	102.65	230.00	201.18
# 0.90	102.93	230.00	201.32
# 1.00	103.22	230.00	201.47
# 1.10	103.50	230.00	201.61
# 1.20	103.79	230.00	201.75
# 1.30	104.07	230.00	201.89
# 1.40	104.35	230.00	202.03
# 1.50	104.62	230.00	202.17
# 1.60	104.90	230.00	202.31
# 1.70	105.18	230.00	202.45
# 1.80	105.45	230.00	202.59
# 1.90	105.72	230.00	202.73
# 2.00	105.99	230.00	202.86
# 2.10	106.26	230.00	203.00
# 2.20	106.53	230.00	203.13
# 2.30	106.80	230.00	203.27
# 2.40	107.07	230.00	203.40
# 2.50	107.33	230.00	203.53
# 2.60	107.59	230.00	203.67
# 2.70	107.86	230.00	203.80
# 2.80	108.12	230.00	203.93
# 2.90	108.38	230.00	204.06
# 3.00	108.64	230.00	204.19
# 3.10	108.89	230.00	204.32
# 3.20	109.15	230.00	204.45
# 3.30	109.40	230.00	204.57
# 3.40	109.65	230.00	204.70
# 3.50	109.91	230.00	204.83
# 3.60	110.16	230.00	204.95
# 3.70	110.41	230.00	205.08
# 3.80	110.65	230.00	205.20
# 3.90	110.90	230.00	205.33
# 4.00	111.15	230.00	205.45
# 4.10	111.39	230.00	205.57
# 4.20	111.63	230.00	205.70
# 4.30	111.88	230.00	205.82
# 4.40	112.12	230.00	205.94
# 4.50	112.36	230.00	206.06
# 4.60	112.59	230.00	206.18
# 4.70	112.83	230.00	206.30
# 4.80	113.07	230.00	206.42
# 4.90	113.30	230.00	206.53
# 5.00	113.53	230.00	206.65
# 5.10	113.77	230.00	206.77
# 5.20	114.00	230.00	206.88
# 5.30	114.23	230.00	207.00
# 5.40	114.46	230.00	207.11
# 5.50	114.68	230.00	207.23
# 5.60	114.91	230.00	207.34
# 5.70	115.14	230.00	207.46
# 5.80	115.36	230.00	207.57
# 5.90	115.58	230.00	207.68
# 6.00	115.81	230.00	207.79
# 6.10	116.03	230.00	207.90
# 6.20	116.25	230.00	208.01
# 6.30	116.47	230.00	208.12
# 6.40	116.68	230.00	208.23
# 6.50	116.90	230.00	208.34
# 6.60	117.12	230.00	208.45
# 6.70	117.33	230.00	208.56
# 6.80	117.54	230.00	208.67
# 6.90	117.76	230.00	208.77
# 7.00	117.97	230.00	208.88
# 7.10	118.18	230.00	208.98
# 7.20	118.39	230.00	209.09
# 7.30	118.59	230.00	209.19
# 7.40	118.80	230.00	209.30
# 7.50	119.01	230.00	209.40
# 7.60	119.21	230.00	209.50
# 7.70	119.42	230.00	209.61
# 7.80	119.62	230.00	209.71
# 7.90	119.82	230.00	209.81
# 8.00	120.02	230.00	209.91
# 8.10	120.22	230.00	210.01
# 8.20	120.42	230.00	210.11
# 8.30	120.62	230.00	210.21
# 8.40	120.82	230.00	210.31
# 8.50	121.01	230.00	210.41
# 8.60	121.21	230.00	210.51
# 8.70	121.40	230.00	210.60
# 8.80	121.59	230.00	210.70
# 8.90	121.79	230.00	210.80
# 9.00	121.98	230.00	210.89
# 9.10	122.17	230.00	210.99
# 9.20	122.36	230.00	211.08
# 9.30	122.54	230.00	211.18
# 9.40	122.73	230.00	211.27
# 9.50	122.92	230.00	211.37
# 9.60	123.10	230.00	211.46
# 9.70	123.29	230.00	211.55
# 9.80	123.47	230.00	211.64
# 9.90	123.65	230.00	211.74
# 10.00	123.84	230.00	211.83
# 10.10	124.02	230.00	211.92
# 10.20	124.20	230.00	212.01
# 10.30	124.38	230.00	212.10
# 10.40	124.55	230.00	212.19
# 10.50	124.73	230.00	212.28
# 10.60	124.91	230.00	212.37
# 10.70	125.08	230.00	212.45
# 10.80	125.26	230.00	212.54
# 10.90	125.43	230.00	212.63
# 11.00	125.60	230.00	212.72
# 11.10	125.78	230.00	212.80
# 11.20	125.95	230.00	212.89
# 11.30	126.12	230.00	212.97
# 11.40	126.29	230.00	213.06
# 11.50	126.45	230.00	213.14
# 11.60	126.62	230.00	213.23
# 11.70	126.79	230.00	213.31
# 11.80	126.96	230.00	213.39
# 11.90	127.12	230.00	213.48
# 12.00	127.29	230.00	213.56
# 12.10	127.45	230.00	213.64
# 12.20	127.61	230.00	213.72
# 12.30	127.77	230.00	213.81
# 12.40	127.93	230.00	213.89
# 12.50	128.09	230.00	213.97
# 12.60	128.25	230.00	214.05
# 12.70	128.41	230.00	214.13
# 12.80	128.57	230.00	214.21
# 12.90	128.73	230.00	214.29
# 13.00	128.88	230.00	214.36
# 13.10	129.04	230.00	214.44
# 13.20	129.20	230.00	214.52
# 13.30	129.35	230.00	214.60
# 13.40	129.50	230.00	214.67
# 13.50	129.65	230.00	214.75
# 13.60	129.81	230.00	214.83
# 13.70	129.96	230.00	214.90
# 13.80	130.11	230.00	214.98
# 13.90	130.26	230.00	215.05
# 14.00	130.41	230.00	215.13
# 14.10	130.55	230.00	215.20
# 14.20	130.70	230.00	215.28
# 14.30	130.85	230.00	215.35
# 14.40	130.99	230.00	215.42
# 14.50	131.14	230.00	215.50
# 14.60	131.28	230.00	215.57
# 14.70	131.43	230.00	215.64
# 14.80	131.57	230.00	215.71
# 14.90	131.71	230.00	215.78
# 15.00	131.85	230.00	215.86
# 15.10	131.99	230.00	215.93
# 15.20	132.13	230.00	216.00
# 15.30	132.27	230.00	216.07
# 15.40	132.41	230.00	216.14
# 15.50	132.55	230.00	216.21
# 15.60	132.69	230.00	216.27
# 15.70	132.82	230.00	216.34
# 15.80	132.96	230.00	216.41
# 15.90	133.09	230.00	216.48
# 16.00	133.23	230.00	216.55
# 16.10	133.36	230.00	216.61
# 16.20	133.50	230.00	216.68
# 16.30	133.63	230.00	216.75
# 16.40	133.76	230.00	216.81
# 16.50	133.89	230.00	216.88
# 16.60	134.02	230.00	216.95
# 16.70	134.15	230.00	217.01
# 16.80	134.28	230.00	217.08
# 16.90	134.41	230.00	217.14
# 17.00	134.54	230.00	217.20
# 17.10	134.66	230.00	217.27
# 17.20	134.79	230.00	217.33
# 17.30	134.92	230.00	217.40
# 17.40	135.04	230.00	217.46
# 17.50	135.17	230.00	217.52
# 17.60	135.29	230.00	217.58
# 17.70	135.42	230.00	217.65
# 17.80	135.54	230.00	217.71
# 17.90	135.66	230.00	217.77
# 18.00	135.78	230.00	217.83
# 18.10	135.90	230.00	217.89
# 18.20	136.02	230.00	217.95
# 18.30	136.14	230.00	218.01
# 18.40	136.26	230.00	218.07
# 18.50	136.38	230.00	218.13
# 18.60	136.50	230.00	218.19
# 18.70	136.62	230.00	218.25
# 18.80	136.73	230.00	218.31
# 18.90	136.85	230.00	218.37
# 19.00	136.97	230.00	218.43
# 19.10	137.08	230.00	218.48
# 19.20	137.20	230.00	218.54
# 19.30	137.31	230.00	218.60
# 19.40	137.42	230.00	218.66
# 19.50	137.54	230.00	218.71
# 19.60	137.65	230.00	218.77
# 19.70	137.76	230.00	218.82
# 19.80	137.87	230.00	218.88
# 19.90	137.98	230.00	218.94
# 20.00	138.09	230.00	218.99
# 20.10	138.20	230.00	219.05
# 20.20	138.31	230.00	219.10
# 20.30	138.42	230.00	219.16
# 20.40	138.53	230.00	219.21
# 20.50	138.63	230.00	219.26
# 20.60	138.74	230.00	219.32
# 20.70	138.85	230.00	219.37
# 20.80	138.95	230.00	219.42
# 20.90	139.06	230.00	219.48
# 21.00	139.16	230.00	219.53
# 21.10	139.27	230.00	219.58
# 21.20	139.37	230.00	219.63
# 21.30	139.47	230.00	219.69
# 21.40	139.58	230.00	219.74
# 21.50	139.68	230.00	219.79
# 21.60	139.78	230.00	219.84
# 21.70	139.88	230.00	219.89
# 21.80	139.98	230.00	219.94
# 21.90	140.08	230.00	219.99
# 22.00	140.18	230.00	220.04
# 22.10	140.28	230.00	220.09
# 22.20	140.38	230.00	220.14
# 22.30	140.48	230.00	220.19
# 22.40	140.58	230.00	220.24
# 22.50	140.67	230.00	220.29
# 22.60	140.77	230.00	220.34
# 22.70	140.87	230.00	220.38
# 22.80	140.96	230.00	220.43
# 22.90	141.06	230.00	220.48
# 23.00	141.15	230.00	220.53
# 23.10	141.25	230.00	220.58
# 23.20	141.34	230.00	220.62
# 23.30	141.43	230.00	220.67
# 23.40	141.53	230.00	220.72
# 23.50	141.62	230.00	220.76
# 23.60	141.71	230.00	220.81
# 23.70	141.80	230.00	220.85
# 23.80	141.89	230.00	220.90
# 23.90	141.98	230.00	220.95
# 24.00	142.07	230.00	220.99
# 24.10	142.16	230.00	221.04
# 24.20	142.25	230.00	221.08
# 24.30	142.34	230.00	221.13
# 24.40	142.43	230.00	221.17
# 24.50	142.52	230.00	221.21
# 24.60	142.60	230.00	221.26
# 24.70	142.69	230.00	221.30
# 24.80	142.78	230.00	221.35
# 24.90	142.86	230.00	221.39
# 25.00	142.95	230.00	221.43
# 25.10	143.03	230.00	221.47
# 25.20	143.12	230.00	221.52
# 25.30	143.20	230.00	221.56
# 25.40	143.29	230.00	221.60
# 25.50	143.37	230.00	221.64
# 25.60	143.45	230.00	221.69
# 25.70	143.54	230.00	221.73
# 25.80	143.62	230.00	221.77
# 25.90	143.70	230.00	221.81
# 26.00	143.78	230.00	221.85
# 26.10	143.86	230.00	221.89
# 26.20	143.94	230.00	221.93
# 26.30	144.02	230.00	221.97
# 26.40	144.10	230.00	222.01
# 26.50	144.18	230.00	222.05
# 26.60	144.26	230.00	222.09
# 26.70	144.34	230.00	222.13
# 26.80	144.42	230.00	222.17
# 26.90	144.50	230.00	222.21
# 27.00	144.58	230.00	222.25
# 27.10	144.65	230.00	222.29
# 27.20	144.73	230.00	222.33
# 27.30	144.81	230.00	222.36
# 27.40	144.88	230.00	222.40
# 27.50	144.96	230.00	222.44
# 27.60	145.03	230.00	222.48
# 27.70	145.11	230.00	222.52
# 27.80	145.18	230.00	222.55
# 27.90	145.26	230.00	222.59
# 28.00	145.33	230.00	222.63
# 28.10	145.40	230.00	222.66
# 28.20	145.48	230.00	222.70
# 28.30	145.55	230.00	222.74
# 28.40	145.62	230.00	222.77
# 28.50	145.69	230.00	222.81
# 28.60	145.76	230.00	222.85
# 28.70	145.84	230.00	222.88
# 28.80	145.91	230.00	222.92
# 28.90	145.98	230.00	222.95
# 29.00	146.05	230.00	222.99
# 29.10	146.12	230.00	223.02
# 29.20	146.19	230.00	223.06
# 29.30	146.26	230.00	223.09
# 29.40	146.32	230.00	223.13
# 29.50	146.39	230.00	223.16
# 29.60	146.46	230.00	223.20
# 29.70	146.53	230.00	223.23
# 29.80	146.60	230.00	223.26
# 29.90	146.66	230.00	223.30
# 30.00	146.73	230.00	223.33
# 30.10	146.80	230.00	223.36
# 30.20	146.86	230.00	223.40
# 30.30	146.93	230.00	223.43
# 30.40	146.99	230.00	223.46
# 30.50	147.06	230.00	223.50
# 30.60	147.12	230.00	223.53
# 30.70	147.19	230.00	223.56
# 30.80	147.25	230.00	223.59
# 30.90	147.31	230.00	223.63
# 31.00	147.38	230.00	223.66
# 31.10	147.44	230.00	223.69
# 31.20	147.50	230.00	223.72
# 31.30	147.57	230.00	223.75
# 31.40	147.63	230.00	223.78
# 31.50	147.69	230.00	223.81
# 31.60	147.75	230.00	223.85
# 31.70	147.81	230.00	223.88
# 31.80	147.87	230.00	223.91
# 31.90	147.93	230.00	223.94
# 32.00	148.00	230.00	223.97
# 32.10	148.06	230.00	224.00
# 32.20	148.11	230.00	224.03
# 32.30	148.17	230.00	224.06
# 32.40	148.23	230.00	224.09
# 32.50	148.29	230.00	224.12
# 32.60	148.35	230.00	224.15
# 32.70	148.41	230.00	224.18
# 32.80	148.47	230.00	224.20
# 32.90	148.52	230.00	224.23
# 33.00	148.58	230.00	224.26
# 33.10	148.64	230.00	224.29
# 33.20	148.70	230.00	224.32
# 33.30	148.75	230.00	224.35
# 33.40	148.81	230.00	224.38
# 33.50	148.86	230.00	224.40
# 33.60	148.92	230.00	224.43
# 33.70	148.98	230.00	224.46
# 33.80	149.03	230.00	224.49
# 33.90	149.09	230.00	224.52
# 34.00	149.14	230.00	224.54
# 34.10	149.19	230.00	224.57
# 34.20	149.25	230.00	224.60
# 34.30	149.30	230.00	224.62
# 34.40	149.36	230.00	224.65
# 34.50	149.41	230.00	224.68
# 34.60	149.46	230.00	224.70
# 34.70	149.51	230.00	224.73
# 34.80	149.57	230.00	224.76
# 34.90	149.62	230.00	224.78
# 35.00	149.67	230.00	224.81
# 35.10	149.72	230.00	224.84
# 35.20	149.77	230.00	224.86
# 35.30	149.83	230.00	224.89
# 35.40	149.88	230.00	224.91
# 35.50	149.93	230.00	224.94
# 35.60	149.98	230.00	224.96
# 35.70	150.03	230.00	224.99
# 35.80	150.08	230.00	225.01
# 35.90	150.13	230.00	225.04
# 36.00	150.18	230.00	225.06
# 36.10	150.23	230.00	225.09
# 36.20	150.27	230.00	225.11
# 36.30	150.32	230.00	225.14
# 36.40	150.37	230.00	225.16
# 36.50	150.42	230.00	225.19
# 36.60	150.47	230.00	225.21
# 36.70	150.51	230.00	225.23
# 36.80	150.56	230.00	225.26
# 36.90	150.61	230.00	225.28
# 37.00	150.66	230.00	225.30
# 37.10	150.70	230.00	225.33
# 37.20	150.75	230.00	225.35
# 37.30	150.80	230.00	225.37
# 37.40	150.84	230.00	225.40
# 37.50	150.89	230.00	225.42
# 37.60	150.93	230.00	225.44
# 37.70	150.98	230.00	225.47
# 37.80	151.02	230.00	225.49
# 37.90	151.07	230.00	225.51
# 38.00	151.11	230.00	225.53
# 38.10	151.16	230.00	225.56
# 38.20	151.20	230.00	225.58
# 38.30	151.25	230.00	225.60
# 38.40	151.29	230.00	225.62
# 38.50	151.33	230.00	225.64
# 38.60	151.38	230.00	225.67
# 38.70	151.42	230.00	225.69
# 38.80	151.46	230.00	225.71
# 38.90	151.51	230.00	225.73
# 39.00	151.55	230.00	225.75
# 39.10	151.59	230.00	225.77
# 39.20	151.63	230.00	225.79
# 39.30	151.67	230.00	225.82
# 39.40	151.72	230.00	225.84
# 39.50	151.76	230.00	225.86
# 39.60	151.80	230.00	225.88
# 39.70	151.84	230.00	225.90
# 39.80	151.88	230.00	225.92
# 39.90	151.92	230.00	225.94
# 40.00	151.96	230.00	225.96
# 40.10	152.00	230.00	225.98
# 40.20	152.04	230.00	226.00
# 40.30	152.08	230.00	226.02
# 40.40	152.12	230.00	226.04
# 40.50	152.16	230.00	226.06
# 40.60	152.20	230.00	226.08
# 40.70	152.24	230.00	226.10
# 40.80	152.28	230.00	226.12
# 40.90	152.32	230.00	226.14
# 41.00	152.35	230.00	226.16
# 41.10	152.39	230.00	226.18
# 41.20	152.43	230.00	226.20
# 41.30	152.47	230.00	226.22
# 41.40	152.51	230.00	226.23
# 41.50	152.54	230.00	226.25
# 41.60	152.58	230.00	226.27
# 41.70	152.62	230.00	226.29
# 41.80	152.65	230.00	226.31
# 41.90	152.69	230.00	226.33
# 42.00	152.73	230.00	226.35
# 42.10	152.76	230.00	226.36
# 42.20	152.80	230.00	226.38
# 42.30	152.84	230.00	226.40
# 42.40	152.87	230.00	226.42
# 42.50	152.91	230.00	226.44
# 42.60	152.94	230.00	226.45
# 42.70	152.98	230.00	226.47
# 42.80	153.01	230.00	226.49
# 42.90	153.05	230.00	226.51
# 43.00	153.08	230.00	226.52
# 43.10	153.12	230.00	226.54
# 43.20	153.15	230.00	226.56
# 43.30	153.19	230.00	226.58
# 43.40	153.22	230.00	226.59
# 43.50	153.25	230.00	226.61
# 43.60	153.29	230.00	226.63
# 43.70	153.32	230.00	226.64
# 43.80	153.36	230.00	226.66
# 43.90	153.39	230.00	226.68
# 44.00	153.42	230.00	226.69
# 44.10	153.45	230.00	226.71
# 44.20	153.49	230.00	226.73
# 44.30	153.52	230.00	226.74
# 44.40	153.55	230.00	226.76
# 44.50	153.58	230.00	226.78
# 44.60	153.62	230.00	226.79
# 44.70	153.65	230.00	226.81
# 44.80	153.68	230.00	226.82
# 44.90	153.71	230.00	226.84
# 45.00	153.74	230.00	226.86
# 45.10	153.77	230.00	226.87
# 45.20	153.81	230.00	226.89
# 45.30	153.84	230.00	226.90
# 45.40	153.87	230.00	226.92
# 45.50	153.90	230.00	226.93
# 45.60	153.93	230.00	226.95
# 45.70	153.96	230.00	226.96
# 45.80	153.99	230.00	226.98
# 45.90	154.02	230.00	226.99
# 46.00	154.05	230.00	227.01
# 46.10	154.08	230.00	227.02
# 46.20	154.11	230.00	227.04
# 46.30	154.14	230.00	227.05
# 46.40	154.17	230.00	227.07
# 46.50	154.20	230.00	227.08
# 46.60	154.23	230.00	227.10
# 46.70	154.25	230.00	227.11
# 46.80	154.28	230.00	227.13
# 46.90	154.31	230.00	227.14
# 47.00	154.34	230.00	227.16
# 47.10	154.37	230.00	227.17
# 47.20	154.40	230.00	227.18
# 47.30	154.42	230.00	227.20
# 47.40	154.45	230.00	227.21
# 47.50	154.48	230.00	227.23
# 47.60	154.51	230.00	227.24
# 47.70	154.54	230.00	227.25
# 47.80	154.56	230.00	227.27
# 47.90	154.59	230.00	227.28
# 48.00	154.62	230.00	227.29
# 48.10	154.64	230.00	227.31
# 48.20	154.67	230.00	227.32
# 48.30	154.70	230.00	227.34
# 48.40	154.72	230.00	227.35
# 48.50	154.75	230.00	227.36
# 48.60	154.78	230.00	227.37
# 48.70	154.80	230.00	227.39
# 48.80	154.83	230.00	227.40
# 48.90	154.85	230.00	227.41
# 49.00	154.88	230.00	227.43
# 49.10	154.91	230.00	227.44
# 49.20	154.93	230.00	227.45
# 49.30	154.96	230.00	227.47
# 49.40	154.98	230.00	227.48
# 49.50	155.01	230.00	227.49
# 49.60	155.03	230.00	227.50
# 49.70	155.06	230.00	227.52
# 49.80	155.08	230.00	227.53
# 49.90	155.11	230.00	227.54
# [(0, 100.3, 230, 200.0),
#  (0.1, 100.5985, 230, 200.15),
#  (0.2, 100.89550750000001, 230, 200.29925),
#  (0.30000000000000004, 101.19102996250001, 230, 200.44775375),
#  (0.4, 101.48507481268751, 230, 200.59551498125),
#  (0.5, 101.77764943862408, 230, 200.74253740634376),
#  (0.6, 102.06876119143097, 230, 200.88882471931203),
#  (0.7, 102.35841738547381, 230, 201.03438059571548),
#  (0.7999999999999999, 102.64662529854644, 230, 201.1792086927369),
#  (0.8999999999999999, 102.9333921720537, 230, 201.32331264927322),
#  (0.9999999999999999, 103.21872521119343, 230, 201.46669608602684),
#  (1.0999999999999999, 103.50263158513746, 230, 201.60936260559671),
#  (1.2, 103.78511842721177, 230, 201.75131579256873),
#  (1.3, 104.06619283507571, 230, 201.8925592136059),
#  (1.4000000000000001, 104.34586187090034, 230, 202.03309641753785),
#  (1.5000000000000002, 104.62413256154584, 230, 202.17293093545015),
#  (1.6000000000000003, 104.9010118987381, 230, 202.3120662807729),
#  (1.7000000000000004, 105.17650683924441, 230, 202.45050594936905),
#  (1.8000000000000005, 105.4506243050482, 230, 202.58825341962222),
#  (1.9000000000000006, 105.72337118352296, 230, 202.7253121525241),
#  (2.0000000000000004, 105.99475432760534, 230, 202.86168559176147),
#  (2.1000000000000005, 106.2647805559673, 230, 202.99737716380267),
#  (2.2000000000000006, 106.53345665318747, 230, 203.13239027798366),
#  (2.3000000000000007, 106.80078936992153, 230, 203.26672832659375),
#  (2.400000000000001, 107.06678542307192, 230, 203.40039468496076),
#  (2.500000000000001, 107.33145149595656, 230, 203.53339271153595),
#  (2.600000000000001, 107.59479423847678, 230, 203.66572574797829),
#  (2.700000000000001, 107.85682026728439, 230, 203.79739711923838),
#  (2.800000000000001, 108.11753616594797, 230, 203.9284101336422),
#  (2.9000000000000012, 108.37694848511823, 230, 204.05876808297398),
#  (3.0000000000000013, 108.63506374269264, 230, 204.18847424255912),
#  (3.1000000000000014, 108.89188842397917, 230, 204.31753187134632),
#  (3.2000000000000015, 109.14742898185928, 230, 204.44594421198957),
#  (3.3000000000000016, 109.40169183694998, 230, 204.57371449092963),
#  (3.4000000000000017, 109.65468337776522, 230, 204.70084591847498),
#  (3.5000000000000018, 109.9064099608764, 230, 204.8273416888826),
#  (3.600000000000002, 110.15687791107202, 230, 204.95320498043822),
#  (3.700000000000002, 110.40609352151665, 230, 205.078438955536),
#  (3.800000000000002, 110.65406305390907, 230, 205.20304676075833),
#  (3.900000000000002, 110.90079273863952, 230, 205.32703152695453),
#  (4.000000000000002, 111.14628877494633, 230, 205.45039636931978),
#  (4.100000000000001, 111.39055733107159, 230, 205.57314438747318),
#  (4.200000000000001, 111.63360454441623, 230, 205.6952786655358),
#  (4.300000000000001, 111.87543652169416, 230, 205.81680227220812),
#  (4.4, 112.11605933908568, 230, 205.93771826084708),
#  (4.5, 112.35547904239026, 230, 206.05802966954283),
#  (4.6, 112.5937016471783, 230, 206.17773952119512),
#  (4.699999999999999, 112.83073313894242, 230, 206.29685082358915),
#  (4.799999999999999, 113.06657947324771, 230, 206.41536656947122),
#  (4.899999999999999, 113.30124657588148, 230, 206.53328973662386),
#  (4.999999999999998, 113.53474034300207, 230, 206.65062328794073),
#  (5.099999999999998, 113.76706664128706, 230, 206.76737017150103),
#  (5.1999999999999975, 113.99823130808062, 230, 206.88353332064352),
#  (5.299999999999997, 114.22824015154022, 230, 206.9991156540403),
#  (5.399999999999997, 114.45709895078252, 230, 207.1141200757701),
#  (5.4999999999999964, 114.6848134560286, 230, 207.22854947539128),
#  (5.599999999999996, 114.91138938874846, 230, 207.3424067280143),
#  (5.699999999999996, 115.13683244180471, 230, 207.45569469437424),
#  (5.799999999999995, 115.3611482795957, 230, 207.56841622090235),
#  (5.899999999999995, 115.58434253819772, 230, 207.68057413979784),
#  (5.999999999999995, 115.80642082550673, 230, 207.79217126909884),
#  (6.099999999999994, 116.0273887213792, 230, 207.90321041275337),
#  (6.199999999999994, 116.2472517777723, 230, 208.0136943606896),
#  (6.299999999999994, 116.46601551888344, 230, 208.12362588888615),
#  (6.399999999999993, 116.68368544128901, 230, 208.2330077594417),
#  (6.499999999999993, 116.90026701408257, 230, 208.3418427206445),
#  (6.5999999999999925, 117.11576567901216, 230, 208.4501335070413),
#  (6.699999999999992, 117.3301868506171, 230, 208.55788283950608),
#  (6.799999999999992, 117.54353591636401, 230, 208.66509342530856),
#  (6.8999999999999915, 117.75581823678219, 230, 208.771767958182),
#  (6.999999999999991, 117.96703914559828, 230, 208.8779091183911),
#  (7.099999999999991, 118.17720394987029, 230, 208.98351957279914),
#  (7.19999999999999, 118.38631793012094, 230, 209.08860197493516),
#  (7.29999999999999, 118.59438634047034, 230, 209.19315896506046),
#  (7.39999999999999, 118.80141440876798, 230, 209.29719317023518),
#  (7.499999999999989, 119.00740733672414, 230, 209.400707204384),
#  (7.599999999999989, 119.21237030004052, 230, 209.50370366836208),
#  (7.699999999999989, 119.41630844854032, 230, 209.60618515002025),
#  (7.799999999999988, 119.61922690629761, 230, 209.70815422427017),
#  (7.899999999999988, 119.82113077176612, 230, 209.8096134531488),
#  (7.999999999999988, 120.02202511790729, 230, 209.91056538588305),
#  (8.099999999999987, 120.22191499231775, 230, 210.01101255895364),
#  (8.199999999999987, 120.42080541735616, 230, 210.11095749615887),
#  (8.299999999999986, 120.61870139026938, 230, 210.2104027086781),
#  (8.399999999999986, 120.81560788331804, 230, 210.3093506951347),
#  (8.499999999999986, 121.01152984390144, 230, 210.407803941659),
#  (8.599999999999985, 121.20647219468194, 230, 210.5057649219507),
#  (8.699999999999985, 121.40043983370853, 230, 210.60323609734098),
#  (8.799999999999985, 121.59343763454, 230, 210.70021991685428),
#  (8.899999999999984, 121.7854704463673, 230, 210.79671881727),
#  (8.999999999999984, 121.97654309413547, 230, 210.89273522318365),
#  (9.099999999999984, 122.16666037866479, 230, 210.98827154706774),
#  (9.199999999999983, 122.35582707677146, 230, 211.0833301893324),
#  (9.299999999999983, 122.5440479413876, 230, 211.17791353838572),
#  (9.399999999999983, 122.73132770168067, 230, 211.2720239706938),
#  (9.499999999999982, 122.91767106317226, 230, 211.36566385084035),
#  (9.599999999999982, 123.1030827078564, 230, 211.45883553158615),
#  (9.699999999999982, 123.28756729431711, 230, 211.5515413539282),
#  (9.799999999999981, 123.47112945784554, 230, 211.64378364715856),
#  (9.89999999999998, 123.6537738105563, 230, 211.73556472892278),
#  (9.99999999999998, 123.83550494150352, 230, 211.82688690527814),
#  (10.09999999999998, 124.016327416796, 230, 211.91775247075176),
#  (10.19999999999998, 124.19624577971203, 230, 212.008163708398),
#  (10.29999999999998, 124.37526455081347, 230, 212.09812288985603),
#  (10.399999999999979, 124.5533882280594, 230, 212.18763227540674),
#  (10.499999999999979, 124.7306212869191, 230, 212.2766941140297),
#  (10.599999999999978, 124.90696818048451, 230, 212.36531064345957),
#  (10.699999999999978, 125.0824333395821, 230, 212.45348409024226),
#  (10.799999999999978, 125.25702117288418, 230, 212.54121666979105),
#  (10.899999999999977, 125.43073606701977, 230, 212.62851058644208),
#  (10.999999999999977, 125.60358238668466, 230, 212.7153680335099),
#  (11.099999999999977, 125.77556447475123, 230, 212.80179119334232),
#  (11.199999999999976, 125.94668665237748, 230, 212.88778223737563),
#  (11.299999999999976, 126.11695321911559, 230, 212.97334332618874),
#  (11.399999999999975, 126.28636845302, 230, 213.0584766095578),
#  (11.499999999999975, 126.4549366107549, 230, 213.14318422651002),
#  (11.599999999999975, 126.62266192770113, 230, 213.22746830537744),
#  (11.699999999999974, 126.78954861806262, 230, 213.31133096385057),
#  (11.799999999999974, 126.9556008749723, 230, 213.3947743090313),
#  (11.899999999999974, 127.12082287059744, 230, 213.47780043748617),
#  (11.999999999999973, 127.28521875624445, 230, 213.5604114352987),
#  (12.099999999999973, 127.44879266246322, 230, 213.64260937812222),
#  (12.199999999999973, 127.6115486991509, 230, 213.72439633123162),
#  (12.299999999999972, 127.77349095565515, 230, 213.80577434957544),
#  (12.399999999999972, 127.93462350087687, 230, 213.88674547782756),
#  (12.499999999999972, 128.0949503833725, 230, 213.96731175043843),
#  (12.599999999999971, 128.25447563145562, 230, 214.04747519168626),
#  (12.69999999999997, 128.41320325329835, 230, 214.12723781572782),
#  (12.79999999999997, 128.57113723703185, 230, 214.20660162664916),
#  (12.89999999999997, 128.7282815508467, 230, 214.28556861851592),
#  (12.99999999999997, 128.88464014309247, 230, 214.36414077542335),
#  (13.09999999999997, 129.04021694237701, 230, 214.44232007154625),
#  (13.199999999999969, 129.19501585766514, 230, 214.5201084711885),
#  (13.299999999999969, 129.3490407783768, 230, 214.59750792883256),
#  (13.399999999999968, 129.50229557448492, 230, 214.6745203891884),
#  (13.499999999999968, 129.6547840966125, 230, 214.75114778724247),
#  (13.599999999999968, 129.80651017612945, 230, 214.82739204830625),
#  (13.699999999999967, 129.9574776252488, 230, 214.90325508806472),
#  (13.799999999999967, 130.10769023712257, 230, 214.97873881262439),
#  (13.899999999999967, 130.25715178593697, 230, 215.0538451185613),
#  (13.999999999999966, 130.40586602700728, 230, 215.12857589296848),
#  (14.099999999999966, 130.55383669687225, 230, 215.20293301350364),
#  (14.199999999999966, 130.7010675133879, 230, 215.27691834843614),
#  (14.299999999999965, 130.84756217582097, 230, 215.35053375669395),
#  (14.399999999999965, 130.99332436494186, 230, 215.42378108791047),
#  (14.499999999999964, 131.13835774311715, 230, 215.4966621824709),
#  (14.599999999999964, 131.28266595440158, 230, 215.56917887155856),
#  (14.699999999999964, 131.42625262462957, 230, 215.6413329772008),
#  (14.799999999999963, 131.56912136150643, 230, 215.71312631231478),
#  (14.899999999999963, 131.7112757546989, 230, 215.7845606807532),
#  (14.999999999999963, 131.8527193759254, 230, 215.85563787734947),
#  (15.099999999999962, 131.99345577904577, 230, 215.9263596879627),
#  (15.199999999999962, 132.13348850015055, 230, 215.9967278895229),
#  (15.299999999999962, 132.2728210576498, 230, 216.06674425007526),
#  (15.399999999999961, 132.41145695236153, 230, 216.1364105288249),
#  (15.499999999999961, 132.54939966759972, 230, 216.20572847618075),
#  (15.59999999999996, 132.68665266926172, 230, 216.27469983379984),
#  (15.69999999999996, 132.8232194059154, 230, 216.34332633463086),
#  (15.79999999999996, 132.95910330888583, 230, 216.41160970295772),
#  (15.89999999999996, 133.0943077923414, 230, 216.4795516544429),
#  (15.99999999999996, 133.22883625337968, 230, 216.5471538961707),
#  (16.09999999999996, 133.3626920721128, 230, 216.61441812668983),
#  (16.19999999999996, 133.49587861175223, 230, 216.6813460360564),
#  (16.29999999999996, 133.62839921869346, 230, 216.74793930587612),
#  (16.399999999999963, 133.7602572226, 230, 216.81419960934673),
#  (16.499999999999964, 133.89145593648698, 230, 216.8801286113),
#  (16.599999999999966, 134.02199865680456, 230, 216.9457279682435),
#  (16.699999999999967, 134.15188866352054, 230, 217.01099932840228),
#  (16.79999999999997, 134.28112922020293, 230, 217.07594433176027),
#  (16.89999999999997, 134.40972357410192, 230, 217.14056461010148),
#  (16.99999999999997, 134.5376749562314, 230, 217.20486178705096),
#  (17.099999999999973, 134.66498658145025, 230, 217.2688374781157),
#  (17.199999999999974, 134.791661648543, 230, 217.33249329072513),
#  (17.299999999999976, 134.91770334030028, 230, 217.3958308242715),
#  (17.399999999999977, 135.04311482359878, 230, 217.45885167015012),
#  (17.49999999999998, 135.1678992494808, 230, 217.5215574117994),
#  (17.59999999999998, 135.2920597532334, 230, 217.5839496247404),
#  (17.69999999999998, 135.4155994544672, 230, 217.6460298766167),
#  (17.799999999999983, 135.5385214571949, 230, 217.7077997272336),
#  (17.899999999999984, 135.6608288499089, 230, 217.76926072859743),
#  (17.999999999999986, 135.78252470565937, 230, 217.83041442495445),
#  (18.099999999999987, 135.90361208213108, 230, 217.8912623528297),
#  (18.19999999999999, 136.02409402172043, 230, 217.95180604106554),
#  (18.29999999999999, 136.14397355161182, 230, 218.01204701086021),
#  (18.39999999999999, 136.26325368385378, 230, 218.0719867758059),
#  (18.499999999999993, 136.3819374154345, 230, 218.1316268419269),
#  (18.599999999999994, 136.5000277283573, 230, 218.19096870771725),
#  (18.699999999999996, 136.61752758971554, 230, 218.25001386417864),
#  (18.799999999999997, 136.73443995176694, 230, 218.30876379485778),
#  (18.9, 136.8507677520081, 230, 218.36721997588347),
#  (19.0, 136.96651391324806, 230, 218.42538387600405),
#  (19.1, 137.08168134368182, 230, 218.48325695662402),
#  (19.200000000000003, 137.19627293696342, 230, 218.5408406718409),
#  (19.300000000000004, 137.3102915722786, 230, 218.5981364684817),
#  (19.400000000000006, 137.4237401144172, 230, 218.65514578613931),
#  (19.500000000000007, 137.53662141384513, 230, 218.7118700572086),
#  (19.60000000000001, 137.6489383067759, 230, 218.76831070692256),
#  (19.70000000000001, 137.76069361524202, 230, 218.82446915338795),
#  (19.80000000000001, 137.8718901471658, 230, 218.880346807621),
#  (19.900000000000013, 137.98253069642996, 230, 218.9359450735829),
#  (20.000000000000014, 138.0926180429478, 230, 218.991265348215),
#  (20.100000000000016, 138.20215495273305, 230, 219.04630902147392),
#  (20.200000000000017, 138.3111441779694, 230, 219.10107747636653),
#  (20.30000000000002, 138.41958845707956, 230, 219.15557208898468),
#  (20.40000000000002, 138.52749051479415, 230, 219.20979422853978),
#  (20.50000000000002, 138.63485306222017, 230, 219.2637452573971),
#  (20.600000000000023, 138.74167879690907, 230, 219.31742653111007),
#  (20.700000000000024, 138.84797040292452, 230, 219.37083939845454),
#  (20.800000000000026, 138.95373055090988, 230, 219.42398520146224),
#  (20.900000000000027, 139.05896189815533, 230, 219.47686527545494),
#  (21.00000000000003, 139.16366708866457, 230, 219.52948094907765),
#  (21.10000000000003, 139.26784875322124, 230, 219.58183354433228),
#  (21.20000000000003, 139.37150950945514, 230, 219.63392437661062),
#  (21.300000000000033, 139.47465196190785, 230, 219.68575475472755),
#  (21.400000000000034, 139.5772787020983, 230, 219.73732598095393),
#  (21.500000000000036, 139.6793923085878, 230, 219.78863935104914),
#  (21.600000000000037, 139.78099534704486, 230, 219.8396961542939),
#  (21.70000000000004, 139.88209037030964, 230, 219.89049767352242),
#  (21.80000000000004, 139.9826799184581, 230, 219.94104518515482),
#  (21.90000000000004, 140.0827665188658, 230, 219.99133995922904),
#  (22.000000000000043, 140.18235268627149, 230, 220.0413832594329),
#  (22.100000000000044, 140.28144092284012, 230, 220.09117634313574),
#  (22.200000000000045, 140.38003371822592, 230, 220.14072046142007),
#  (22.300000000000047, 140.47813354963478, 230, 220.19001685911297),
#  (22.40000000000005, 140.5757428818866, 230, 220.2390667748174),
#  (22.50000000000005, 140.67286416747717, 230, 220.28787144094332),
#  (22.60000000000005, 140.76949984663977, 230, 220.3364320837386),
#  (22.700000000000053, 140.86565234740658, 230, 220.38474992331987),
#  (22.800000000000054, 140.96132408566956, 230, 220.4328261737033),
#  (22.900000000000055, 141.0565174652412, 230, 220.48066204283478),
#  (23.000000000000057, 141.151234877915, 230, 220.5282587326206),
#  (23.10000000000006, 141.2454787035254, 230, 220.5756174389575),
#  (23.20000000000006, 141.33925131000777, 230, 220.6227393517627),
#  (23.30000000000006, 141.43255505345772, 230, 220.66962565500387),
#  (23.400000000000063, 141.52539227819042, 230, 220.71627752672885),
#  (23.500000000000064, 141.61776531679948, 230, 220.76269613909523),
#  (23.600000000000065, 141.7096764902155, 230, 220.80888265839974),
#  (23.700000000000067, 141.8011281077644, 230, 220.85483824510774),
#  (23.800000000000068, 141.8921224672256, 230, 220.9005640538822),
#  (23.90000000000007, 141.98266185488947, 230, 220.9460612336128),
#  (24.00000000000007, 142.072748545615, 230, 220.99133092744472),
#  (24.100000000000072, 142.16238480288695, 230, 221.0363742728075),
#  (24.200000000000074, 142.2515728788725, 230, 221.08119240144347),
#  (24.300000000000075, 142.34031501447814, 230, 221.12578643943624),
#  (24.400000000000077, 142.42861343940575, 230, 221.17015750723908),
#  (24.500000000000078, 142.51647037220872, 230, 221.21430671970288),
#  (24.60000000000008, 142.60388802034768, 230, 221.25823518610434),
#  (24.70000000000008, 142.69086858024593, 230, 221.30194401017383),
#  (24.800000000000082, 142.77741423734471, 230, 221.34543429012297),
#  (24.900000000000084, 142.86352716615798, 230, 221.38870711867236),
#  (25.000000000000085, 142.94920953032718, 230, 221.43176358307898),
#  (25.100000000000087, 143.03446348267553, 230, 221.47460476516358),
#  (25.200000000000088, 143.11929116526215, 230, 221.51723174133775),
#  (25.30000000000009, 143.20369470943584, 230, 221.55964558263108),
#  (25.40000000000009, 143.28767623588865, 230, 221.6018473547179),
#  (25.500000000000092, 143.37123785470922, 230, 221.6438381179443),
#  (25.600000000000094, 143.45438166543568, 230, 221.6856189273546),
#  (25.700000000000095, 143.5371097571085, 230, 221.72719083271784),
#  (25.800000000000097, 143.61942420832295, 230, 221.76855487855426),
#  (25.900000000000098, 143.70132708728133, 230, 221.80971210416146),
#  (26.0000000000001, 143.7828204518449, 230, 221.85066354364068),
#  (26.1000000000001, 143.86390634958568, 230, 221.89141022592247),
#  (26.200000000000102, 143.94458681783775, 230, 221.93195317479285),
#  (26.300000000000104, 144.02486388374857, 230, 221.97229340891886),
#  (26.400000000000105, 144.10473956432983, 230, 222.0124319418743),
#  (26.500000000000107, 144.1842158665082, 230, 222.05236978216493),
#  (26.600000000000108, 144.26329478717565, 230, 222.0921079332541),
#  (26.70000000000011, 144.34197831323976, 230, 222.13164739358783),
#  (26.80000000000011, 144.42026842167357, 230, 222.1709891566199),
#  (26.900000000000112, 144.4981670795652, 230, 222.21013421083677),
#  (27.000000000000114, 144.57567624416737, 230, 222.2490835397826),
#  (27.100000000000115, 144.65279786294653, 230, 222.28783812208368),
#  (27.200000000000117, 144.7295338736318, 230, 222.32639893147325),
#  (27.300000000000118, 144.80588620426363, 230, 222.3647669368159),
#  (27.40000000000012, 144.8818567732423, 230, 222.40294310213181),
#  (27.50000000000012, 144.95744748937608, 230, 222.44092838662115),
#  (27.600000000000122, 145.0326602519292, 230, 222.47872374468804),
#  (27.700000000000124, 145.10749695066954, 230, 222.5163301259646),
#  (27.800000000000125, 145.1819594659162, 230, 222.55374847533477),
#  (27.900000000000126, 145.25604966858663, 230, 222.5909797329581),
#  (28.000000000000128, 145.3297694202437, 230, 222.6280248342933),
#  (28.10000000000013, 145.4031205731425, 230, 222.66488471012184),
#  (28.20000000000013, 145.4761049702768, 230, 222.70156028657124),
#  (28.300000000000132, 145.54872444542542, 230, 222.73805248513838),
#  (28.400000000000134, 145.6209808231983, 230, 222.7743622227127),
#  (28.500000000000135, 145.6928759190823, 230, 222.81049041159915),
#  (28.600000000000136, 145.76441153948687, 230, 222.84643795954116),
#  (28.700000000000138, 145.83558948178944, 230, 222.88220576974345),
#  (28.80000000000014, 145.90641153438048, 230, 222.91779474089472),
#  (28.90000000000014, 145.97687947670858, 230, 222.95320576719024),
#  (29.000000000000142, 146.04699507932503, 230, 222.9884397383543),
#  (29.100000000000144, 146.1167601039284, 230, 223.02349753966251),
#  (29.200000000000145, 146.18617630340879, 230, 223.0583800519642),
#  (29.300000000000146, 146.25524542189174, 230, 223.0930881517044),
#  (29.400000000000148, 146.32396919478228, 230, 223.12762271094587),
#  (29.50000000000015, 146.39234934880838, 230, 223.16198459739115),
#  (29.60000000000015, 146.46038760206434, 230, 223.19617467440418),
#  (29.700000000000152, 146.52808566405403, 230, 223.23019380103216),
#  (29.800000000000153, 146.59544523573376, 230, 223.26404283202703),
#  (29.900000000000155, 146.66246800955508, 230, 223.2977226178669),
#  (30.000000000000156, 146.72915566950732, 230, 223.33123400477754),
#  (30.100000000000158, 146.79550989115978, 230, 223.36457783475367),
#  (30.20000000000016, 146.861532341704, 230, 223.3977549455799),
#  (30.30000000000016, 146.92722467999548, 230, 223.430766170852),
#  (30.400000000000162, 146.9925885565955, 230, 223.46361233999772),
#  (30.500000000000163, 147.05762561381252, 230, 223.49629427829774),
#  (30.600000000000165, 147.12233748574346, 230, 223.52881280690627),
#  (30.700000000000166, 147.18672579831474, 230, 223.56116874287173),
#  (30.800000000000168, 147.25079216932318, 230, 223.59336289915737),
#  (30.90000000000017, 147.31453820847656, 230, 223.6253960846616),
#  (31.00000000000017, 147.37796551743418, 230, 223.65726910423828),
#  (31.100000000000172, 147.441075689847, 230, 223.6889827587171),
#  (31.200000000000173, 147.50387031139775, 230, 223.7205378449235),
#  (31.300000000000175, 147.56635095984075, 230, 223.75193515569887),
#  (31.400000000000176, 147.62851920504156, 230, 223.78317547992037),
#  (31.500000000000178, 147.69037660901634, 230, 223.8142596025208),
#  (31.60000000000018, 147.75192472597126, 230, 223.84518830450816),
#  (31.70000000000018, 147.8131651023414, 230, 223.87596236298563),
#  (31.800000000000182, 147.8740992768297, 230, 223.9065825511707),
#  (31.900000000000183, 147.93472878044554, 230, 223.93704963841486),
#  (32.000000000000185, 147.9950551365433, 230, 223.96736439022277),
#  (32.100000000000186, 148.0550798608606, 230, 223.99752756827166),
#  (32.20000000000019, 148.11480446155628, 230, 224.0275399304303),
#  (32.30000000000019, 148.1742304392485, 230, 224.05740223077814),
#  (32.40000000000019, 148.23335928705225, 230, 224.08711521962425),
#  (32.50000000000019, 148.292192490617, 230, 224.11667964352614),
#  (32.60000000000019, 148.35073152816392, 230, 224.1460962453085),
#  (32.700000000000195, 148.4089778705231, 230, 224.17536576408196),
#  (32.800000000000196, 148.4669329811705, 230, 224.20448893526157),
#  (32.9000000000002, 148.52459831626464, 230, 224.23346649058524),
#  (33.0000000000002, 148.58197532468333, 230, 224.26229915813232),
#  (33.1000000000002, 148.6390654480599, 230, 224.29098766234165),
#  (33.2000000000002, 148.69587012081962, 230, 224.31953272402995),
#  (33.3000000000002, 148.75239077021553, 230, 224.3479350604098),
#  (33.400000000000205, 148.80862881636446, 230, 224.37619538510776),
#  (33.500000000000206, 148.86458567228263, 230, 224.40431440818224),
#  (33.60000000000021, 148.92026274392123, 230, 224.4322928361413),
#  (33.70000000000021, 148.97566143020163, 230, 224.4601313719606),
#  (33.80000000000021, 149.0307831230506, 230, 224.4878307151008),
#  (33.90000000000021, 149.08562920743535, 230, 224.5153915615253),
#  (34.00000000000021, 149.14020106139816, 230, 224.54281460371766),
#  (34.100000000000215, 149.19450005609116, 230, 224.57010053069908),
#  (34.200000000000216, 149.2485275558107, 230, 224.59725002804558),
#  (34.30000000000022, 149.30228491803166, 230, 224.62426377790536),
#  (34.40000000000022, 149.3557734934415, 230, 224.65114245901583),
#  (34.50000000000022, 149.4089946259743, 230, 224.67788674672073),
#  (34.60000000000022, 149.46194965284442, 230, 224.70449731298714),
#  (34.70000000000022, 149.5146399045802, 230, 224.7309748264222),
#  (34.800000000000225, 149.5670667050573, 230, 224.75731995229012),
#  (34.900000000000226, 149.619231371532, 230, 224.78353335252865),
#  (35.00000000000023, 149.67113521467434, 230, 224.809615685766),
#  (35.10000000000023, 149.72277953860097, 230, 224.83556760733717),
#  (35.20000000000023, 149.77416564090797, 230, 224.8613897693005),
#  (35.30000000000023, 149.82529481270342, 230, 224.887082820454),
#  (35.40000000000023, 149.8761683386399, 230, 224.9126474063517),
#  (35.500000000000234, 149.9267874969467, 230, 224.93808416931995),
#  (35.600000000000236, 149.97715355946198, 230, 224.96339374847335),
#  (35.70000000000024, 150.02726779166468, 230, 224.98857677973098),
#  (35.80000000000024, 150.07713145270637, 230, 225.01363389583236),
#  (35.90000000000024, 150.12674579544284, 230, 225.03856572635317),
#  (36.00000000000024, 150.17611206646563, 230, 225.06337289772142),
#  (36.10000000000024, 150.2252315061333, 230, 225.08805603323282),
#  (36.200000000000244, 150.27410534860263, 230, 225.11261575306665),
#  (36.300000000000246, 150.32273482185963, 230, 225.13705267430132),
#  (36.40000000000025, 150.37112114775033, 230, 225.1613674109298),
#  (36.50000000000025, 150.41926554201157, 230, 225.18556057387516),
#  (36.60000000000025, 150.46716921430152, 230, 225.20963277100577),
#  (36.70000000000025, 150.51483336823, 230, 225.23358460715076),
#  (36.80000000000025, 150.56225920138885, 230, 225.25741668411501),
#  (36.900000000000254, 150.6094479053819, 230, 225.28112960069444),
#  (37.000000000000256, 150.656400665855, 230, 225.30472395269095),
#  (37.10000000000026, 150.70311866252572, 230, 225.3282003329275),
#  (37.20000000000026, 150.7496030692131, 230, 225.35155933126288),
#  (37.30000000000026, 150.79585505386703, 230, 225.37480153460655),
#  (37.40000000000026, 150.84187577859768, 230, 225.39792752693353),
#  (37.50000000000026, 150.8876663997047, 230, 225.42093788929884),
#  (37.600000000000264, 150.93322806770618, 230, 225.44383319985235),
#  (37.700000000000266, 150.97856192736765, 230, 225.4666140338531),
#  (37.80000000000027, 151.0236691177308, 230, 225.48928096368383),
#  (37.90000000000027, 151.06855077214215, 230, 225.51183455886542),
#  (38.00000000000027, 151.11320801828143, 230, 225.53427538607107),
#  (38.10000000000027, 151.15764197819001, 230, 225.5566040091407),
#  (38.20000000000027, 151.20185376829906, 230, 225.578820989095),
#  (38.300000000000274, 151.24584449945758, 230, 225.60092688414954),
#  (38.400000000000276, 151.2896152769603, 230, 225.6229222497288),
#  (38.50000000000028, 151.3331672005755, 230, 225.64480763848013),
#  (38.60000000000028, 151.37650136457262, 230, 225.66658360028777),
#  (38.70000000000028, 151.41961885774975, 230, 225.6882506822863),
#  (38.80000000000028, 151.46252076346101, 230, 225.70980942887488),
#  (38.90000000000028, 151.5052081596437, 230, 225.73126038173052),
#  (39.000000000000284, 151.54768211884547, 230, 225.75260407982185),
#  (39.100000000000286, 151.58994370825124, 230, 225.77384105942275),
#  (39.20000000000029, 151.63199398971, 230, 225.7949718541256),
#  (39.30000000000029, 151.67383401976144, 230, 225.815996994855),
#  (39.40000000000029, 151.71546484966262, 230, 225.83691700988072),
#  (39.50000000000029, 151.7568875254143, 230, 225.8577324248313),
#  (39.60000000000029, 151.79810308778724, 230, 225.87844376270715),
#  (39.700000000000294, 151.8391125723483, 230, 225.89905154389362),
#  (39.800000000000296, 151.87991700948658, 230, 225.91955628617416),
#  (39.9000000000003, 151.92051742443914, 230, 225.9399585047433),
#  (40.0000000000003, 151.96091483731695, 230, 225.96025871221957),
#  (40.1000000000003, 152.00111026313036, 230, 225.9804574186585),
#  (40.2000000000003, 152.0411047118147, 230, 226.0005551315652),
#  (40.3000000000003, 152.08089918825564, 230, 226.02055235590734),
#  (40.400000000000304, 152.12049469231437, 230, 226.04044959412784),
#  (40.500000000000306, 152.1598922188528, 230, 226.06024734615718),
#  (40.60000000000031, 152.19909275775854, 230, 226.0799461094264),
#  (40.70000000000031, 152.23809729396973, 230, 226.09954637887927),
#  (40.80000000000031, 152.27690680749987, 230, 226.11904864698488),
#  (40.90000000000031, 152.31552227346236, 230, 226.13845340374993),
#  (41.00000000000031, 152.35394466209505, 230, 226.15776113673118),
#  (41.100000000000314, 152.39217493878456, 230, 226.17697233104752),
#  (41.200000000000315, 152.43021406409065, 230, 226.1960874693923),
#  (41.30000000000032, 152.4680629937702, 230, 226.21510703204532),
#  (41.40000000000032, 152.50572267880133, 230, 226.2340314968851),
#  (41.50000000000032, 152.54319406540733, 230, 226.25286133940068),
#  (41.60000000000032, 152.5804780950803, 230, 226.27159703270365),
#  (41.70000000000032, 152.61757570460492, 230, 226.29023904754015),
#  (41.800000000000324, 152.6544878260819, 230, 226.30878785230246),
#  (41.900000000000325, 152.69121538695148, 230, 226.32724391304095),
#  (42.00000000000033, 152.72775931001672, 230, 226.34560769347576),
#  (42.10000000000033, 152.76412051346665, 230, 226.36387965500836),
#  (42.20000000000033, 152.80029991089933, 230, 226.38206025673333),
#  (42.30000000000033, 152.83629841134484, 230, 226.40014995544965),
#  (42.40000000000033, 152.87211691928812, 230, 226.41814920567242),
#  (42.500000000000334, 152.90775633469167, 230, 226.43605845964407),
#  (42.600000000000335, 152.9432175530182, 230, 226.45387816734583),
#  (42.70000000000034, 152.97850146525312, 230, 226.4716087765091),
#  (42.80000000000034, 153.01360895792686, 230, 226.48925073262654),
#  (42.90000000000034, 153.04854091313723, 230, 226.50680447896343),
#  (43.00000000000034, 153.08329820857153, 230, 226.52427045656862),
#  (43.10000000000034, 153.1178817175287, 230, 226.54164910428577),
#  (43.200000000000344, 153.15229230894104, 230, 226.55894085876434),
#  (43.300000000000345, 153.18653084739634, 230, 226.5761461544705),
#  (43.40000000000035, 153.22059819315936, 230, 226.59326542369817),
#  (43.50000000000035, 153.25449520219357, 230, 226.6102990965797),
#  (43.60000000000035, 153.2882227261826, 230, 226.62724760109677),
#  (43.70000000000035, 153.3217816125517, 230, 226.6441113630913),
#  (43.80000000000035, 153.35517270448892, 230, 226.66089080627586),
#  (43.900000000000354, 153.38839684096646, 230, 226.67758635224448),
#  (44.000000000000355, 153.42145485676164, 230, 226.69419842048325),
#  (44.10000000000036, 153.45434758247782, 230, 226.71072742838084),
#  (44.20000000000036, 153.48707584456542, 230, 226.7271737912389),
#  (44.30000000000036, 153.5196404653426, 230, 226.7435379222827),
#  (44.40000000000036, 153.5520422630159, 230, 226.7598202326713),
#  (44.50000000000036, 153.58428205170082, 230, 226.77602113150795),
#  (44.600000000000364, 153.61636064144233, 230, 226.7921410258504),
#  (44.700000000000365, 153.64827883823511, 230, 226.80818032072116),
#  (44.80000000000037, 153.68003744404393, 230, 226.82413941911756),
#  (44.90000000000037, 153.7116372568237, 230, 226.84001872202197),
#  (45.00000000000037, 153.74307907053958, 230, 226.85581862841184),
#  (45.10000000000037, 153.7743636751869, 230, 226.8715395352698),
#  (45.20000000000037, 153.80549185681096, 230, 226.88718183759346),
#  (45.300000000000374, 153.8364643975269, 230, 226.90274592840547),
#  (45.400000000000375, 153.86728207553926, 230, 226.91823219876346),
#  (45.50000000000038, 153.89794566516156, 230, 226.93364103776963),
#  (45.60000000000038, 153.92845593683575, 230, 226.94897283258078),
#  (45.70000000000038, 153.95881365715158, 230, 226.96422796841787),
#  (45.80000000000038, 153.98901958886583, 230, 226.9794068285758),
#  (45.90000000000038, 154.0190744909215, 230, 226.99450979443293),
#  (46.000000000000384, 154.0489791184669, 230, 227.00953724546076),
#  (46.100000000000385, 154.07873422287454, 230, 227.02448955923344),
#  (46.20000000000039, 154.10834055176016, 230, 227.0393671114373),
#  (46.30000000000039, 154.13779884900137, 230, 227.0541702758801),
#  (46.40000000000039, 154.16710985475638, 230, 227.06889942450067),
#  (46.50000000000039, 154.1962743054826, 230, 227.0835549273782),
#  (46.60000000000039, 154.2252929339552, 230, 227.0981371527413),
#  (46.700000000000394, 154.25416646928542, 230, 227.1126464669776),
#  (46.800000000000395, 154.282895636939, 230, 227.12708323464273),
#  (46.9000000000004, 154.3114811587543, 230, 227.1414478184695),
#  (47.0000000000004, 154.33992375296054, 230, 227.15574057937715),
#  (47.1000000000004, 154.36822413419574, 230, 227.16996187648027),
#  (47.2000000000004, 154.39638301352477, 230, 227.18411206709789),
#  (47.3000000000004, 154.42440109845714, 230, 227.19819150676238),
#  (47.400000000000404, 154.45227909296486, 230, 227.21220054922856),
#  (47.500000000000405, 154.48001769750005, 230, 227.22613954648244),
#  (47.600000000000406, 154.50761760901256, 230, 227.24000884875002),
#  (47.70000000000041, 154.53507952096749, 230, 227.25380880450626),
#  (47.80000000000041, 154.56240412336265, 230, 227.26753976048374),
#  (47.90000000000041, 154.58959210274585, 230, 227.2812020616813),
#  (48.00000000000041, 154.61664414223213, 230, 227.29479605137294),
#  (48.10000000000041, 154.64356092152096, 230, 227.30832207111607),
#  (48.200000000000415, 154.67034311691336, 230, 227.32178046076046),
#  (48.300000000000416, 154.6969914013288, 230, 227.3351715584567),
#  (48.40000000000042, 154.72350644432217, 230, 227.3484957006644),
#  (48.50000000000042, 154.74988891210054, 230, 227.3617532221611),
#  (48.60000000000042, 154.77613946754005, 230, 227.3749444560503),
#  (48.70000000000042, 154.80225877020234, 230, 227.38806973377),
#  (48.80000000000042, 154.82824747635132, 230, 227.40112938510117),
#  (48.900000000000425, 154.85410623896956, 230, 227.41412373817565),
#  (49.000000000000426, 154.8798357077747, 230, 227.42705311948478),
#  (49.10000000000043, 154.90543652923583, 230, 227.43991785388735),
#  (49.20000000000043, 154.93090934658966, 230, 227.4527182646179),
#  (49.30000000000043, 154.9562547998567, 230, 227.46545467329483),
#  (49.40000000000043, 154.98147352585744, 230, 227.47812739992835),
#  (49.50000000000043, 155.00656615822814, 230, 227.49073676292872),
#  (49.600000000000435, 155.031533327437, 230, 227.50328307911406),
#  (49.700000000000436, 155.0563756607998, 230, 227.5157666637185),
#  (49.80000000000044, 155.0810937824958, 230, 227.5281878303999),
#  (49.90000000000044, 155.10568831358333, 230, 227.5405468912479)]

# %% [markdown]
# ### 1. Базовый эксперимент:
#
# - Параметры: C = 100, I = 50, G = 70, X = 30, M = 20, Y* = 200, k = 0.5, Pe = 100.
# - Цель: Наблюдать изменения уровня цен и динамику спроса и предложения в экономике.

# %%
C, I, G, X, M = 100, 50, 70, 30, 20
Y_star, k, Pe = 200, 0.5, 100

def AD(P) -> float:
    return (C + I + G + (X - M)) - 0.5 * P  # AD = 230 - 0.5P

def AS(P) -> float:
    return Y_star + k * (P - Pe) # AS = 200 + 0.5(P - 100)

P_eq = 80  # Решение уравнения 230 - 0.5P = 200 + 0.5(P - 100)
Y_eq = AD(P_eq)

P_range = np.linspace(50, 150, 100)
Y_AD = [AD(p) for p in P_range]
Y_AS = [AS(p) for p in P_range]

plt.figure(figsize=(12, 7))
plt.plot(Y_AD, 
         P_range, 
         lw=2.5, 
         color='#1f77b4', 
         label='AD: $230 - 0.5P$',
         )

plt.plot(Y_AS, 
         P_range, 
         lw=2.5, 
         color='#ff7f0e', 
         label='AS: $200 + 0.5(P - 100)$',
         )
plt.scatter(Y_eq, 
            P_eq, 
            s=100, 
            color='red',
            zorder=5, 
            label=f'Равновесие (Y={Y_eq}, P={P_eq})'
            )

plt.title('Равновесие в модели AD-AS', fontsize=16, pad=20)
plt.xlabel('Реальный выпуск (Y)', fontsize=12)
plt.ylabel('Уровень цен (P)', fontsize=12)
plt.xticks(np.arange(150, 250, 10))
plt.yticks(np.arange(50, 160, 10))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(frameon=True, loc='upper right', fontsize=10)
plt.annotate('Точка равновесия:\nP=80, Y=190', 
             xy=(Y_eq, P_eq), 
             xytext=(180, 60),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10)

plt.show()

# %% [markdown]
# ### Анализ графика:
#
# **Кривая AD (синяя)**:
#
# Отражает обратную зависимость между уровнем цен (P) и совокупным спросом.
# Пример: При P=100 → Y_AD = 230 - 0.5*100 = 180.
#
# **Кривая AS (оранжевая)**:
#
# Показывает прямую зависимость между P и объемом предложения.
# Пример: При P=100 → Y_AS = 200 + 0.5*(100 - 100) = 200.
#
# **Равновесие (красная точка)**:
#
# Пересечение AD и AS определяет равновесные значения:
#
# Y=190 (выпуск ниже потенциального Y*=200 из-за инфляции).
#
# P=80 (фактический уровень цен ниже ожидаемого Pe=100).
#
# ---
#
# ### Интерпретация:
#
# **Почему выпуск ниже Y*?**
#
# Фирмы ожидали уровень цен Pe=100, но фактический P=80 оказался ниже. Это заставляет их сокращать производство (Y=190 < Y*=200).
#
# **Эффект «неверных ожиданий»:**
#
# Если фактические цены отличаются от ожидаемых, возникает дисбаланс между спросом и предложением, что приводит к колебаниям выпуска.
#
# ---

# %%
G_new = 100

def AD_old(P):
    return 230 - 0.5 * P

def AD_new(P):
    return (C + I + G_new + (X - M)) - 0.5 * P  # AD = 260 - 0.5P

P_eq_new = 110  # Решение: 260 - 0.5P = 200 + 0.5(P - 100)
Y_eq_new = AD_new(P_eq_new)

plt.figure(figsize=(12, 7))

plt.plot(Y_AD,
         P_range,
         lw=2, 
         color='#1f77b4', 
         linestyle='--', 
         label='Исходный AD: $230 - 0.5P$',
         )

plt.plot([AD_new(p) for p in P_range], 
         P_range, 
         lw=2.5, 
         color='#1f77b4', 
         label='Новый AD: $260 - 0.5P$',
         )

plt.plot(Y_AS, 
         P_range, 
         lw=2.5, 
         color='#ff7f0e', 
         label='AS: $200 + 0.5(P - 100)$',
         )

plt.scatter(Y_eq, 
            P_eq, 
            s=100, 
            color='red', 
            zorder=5, 
            label=f'Исходное равновесие (Y=190, P=80)',
            )

plt.scatter(Y_eq_new, 
            P_eq_new, 
            s=100, 
            color='purple', 
            zorder=5, 
            label=f'Новое равновесие (Y=205, P=110)',
            )

plt.title('Эффект увеличения государственных расходов (G↑)', fontsize=16, pad=20)
plt.xlabel('Реальный выпуск (Y)', fontsize=12)
plt.ylabel('Уровень цен (P)', fontsize=12)
plt.xticks(np.arange(150, 270, 10))
plt.yticks(np.arange(50, 160, 10))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(frameon=True, loc='upper right', fontsize=10)

plt.annotate('Стимулирование спроса:\nG увеличивается на 30', 
             xy=(220, 100), 
             xytext=(180, 130),
             fontsize=10,
             color='green')

plt.show()

# %% [markdown]
# ### Анализ графика:
#
# **Сдвиг AD вправо:**
#
# Увеличение G на 30 единиц привело к параллельному сдвигу кривой AD вправо (синяя пунктирная → синяя сплошная).
# Пример: При P=100 → Y_AD = 260 - 0.5*100 = 210 (было 180).
#
# **Новое равновесие (фиолетовая точка):**
#
# * Выпуск вырос до Y=205 (превысил потенциальный Y*=200).
#
# * Цены выросли до P=110 (инфляция).
#
# **Эффект «перегрева экономики»:**
#
# * Краткосрочный рост Y выше Y* возможен из-за:
#
# * Увеличения загрузки производственных мощностей,
#
# * Сверхурочной работы сотрудников,
#
# * Временного игнорирования инфляционных ожиданий.
#
# ---
#
# ### Интерпретация:
#
# **Механизм стимулирования:**
#
# Государство, увеличивая расходы (например, на инфраструктуру или соцпрограммы), напрямую повышает совокупный спрос. Это создает мультипликативный эффект: рост доходов → увеличение потребления → дальнейший рост AD.
#
# **Инфляционные риски:**
# Рост цен (P=80 → 110) объясняется:
#
# * Усилением давления спроса на ограниченные ресурсы,
#
# * Ростом издержек производства (например, зарплаты).
#
# **Долгосрочные последствия:**
#
# Со временем фирмы пересмотрят инфляционные ожидания (Pe вырастет), что сдвинет AS влево. Это вернет Y к Y*=200, но при более высоком уровне цен (например, P=120).
#
# ---

# %% [markdown]
# ### 3. Шок предложения:
#
# - Увеличить Pe до 120 (ожидаемое повышение цен).
# - Цель: Понять, как ожидания влияют на равновесие.
#
# ---

# %%
Pe_new = 120

def AS_old(P):
    return 200 + 0.5 * (P - 100) 

def AS_new(P):
    return 200 + 0.5 * (P - Pe_new) 

# Равновесие после шока
P_eq_shock = 90  # Решение: 230 - 0.5P = 140 + 0.5P → P=90
Y_eq_shock = AD_old(P_eq_shock)  # Y=230 - 0.5*90=185

plt.figure(figsize=(12, 7))

plt.plot(Y_AD, 
         P_range, 
         lw=2.5, 
         color='#1f77b4', 
         label='AD: $230 - 0.5P$',
         )

plt.plot(Y_AS, 
         P_range, 
         lw=2, 
         color='#ff7f0e', 
         linestyle='--', 
         label='Исходная AS: $200 + 0.5(P-100)$'
         )

plt.plot([AS_new(p) for p in P_range],
         P_range, 
         lw=2.5, 
         color='#ff7f0e', 
         label='Новая AS: $140 + 0.5P$'
         )

plt.scatter(Y_eq, 
            P_eq, 
            s=100,
            color='red', 
            zorder=5, 
            label=f'Исходное равновесие (Y=190, P=80)'
            )

plt.scatter(Y_eq_shock, 
            P_eq_shock, 
            s=100, 
            color='purple', 
            zorder=5, 
            label=f'Новое равновесие (Y=185, P=90)',
            )

plt.title('Шок предложения: Рост инфляционных ожиданий (Pe↑)', fontsize=16, pad=20)
plt.xlabel('Реальный выпуск (Y)', fontsize=12)
plt.ylabel('Уровень цен (P)', fontsize=12)
plt.xticks(np.arange(150, 250, 10))
plt.yticks(np.arange(50, 160, 10))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(frameon=True, loc='upper right', fontsize=10)

plt.annotate('Шок предложения:\nPe увеличивается до 120', 
             xy=(180, 100), 
             xytext=(180, 120),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10,
             color='green')

plt.show()

# %% [markdown]
# ### Анализ графика:
#
# **Сдвиг AS влево**:
#
# * Рост Pe на 20 единиц привел к сдвигу кривой AS влево (оранжевая пунктирная → оранжевая сплошная).
# * Пример: При P=100 → Y_AS = 140 + 0.5*100 = 190 (было 200).
#
# **Новое равновесие (фиолетовая точка):**
#
# * Выпуск снизился до Y=185 (дальше от потенциального Y*=200).
#
# * Цены выросли до P=90 (инфляция).
#
# **Стагфляция:**
#
# * Одновременное падение выпуска и рост цен — характерный признак шока предложения. Причины:
#
# * Фирмы ожидают роста издержек (например, зарплат или цен на ресурсы),
#
# * Сокращают производство, чтобы избежать убытков
#
# ---
#
# ### Интерпретация:
#
# * Механизм шока:
#
# Если фирмы ожидают роста цен (Pe↑), они:
#
#     1. Закладывают будущие издержки в текущие цены,
#
#     2. Сокращают инвестиции и производство,
#
#     3. Перекладывают риски на потребителей через повышение P.
#
# * Эффект «самореализующихся ожиданий»:
# Рост Pe может спровоцировать реальную инфляцию, даже если первоначальные предпосылки были необоснованны.
#
# * Долгосрочные последствия:
# Чтобы вернуть выпуск к Y*=200, Центральный банк должен либо:
#
#     1. Снизить фактические цены (например, через жесткую денежную политику),
#
#     2. Убедить фирмы в стабильности цен (снизить Pe).

# %% [markdown]
# ### 4. Снижение инвестиций:
#
# - Уменьшить I до 20.
# - Цель: Исследовать последствия сокращения инвестиций на экономическую стабильность.
#
# ---

# %%
I_new = 20

def AD_old(P):
    return 230 - 0.5 * P  

def AD_new(P):
    return (C + I_new + G + (X - M)) - 0.5 * P  # AD = 200 - 0.5P

P_eq_shock = 50  # Решение: 200 - 0.5P = 200 + 0.5(P - 100) → P=50
Y_eq_shock = AD_new(P_eq_shock)  # Y=200 - 0.5*50=175


plt.figure(figsize=(12, 7))

plt.plot(Y_AD, 
         P_range, 
         lw=2, 
         color='#1f77b4', 
         linestyle='--', 
         label='Исходный AD: $230 - 0.5P$',
         )

plt.plot([AD_new(p) for p in P_range], 
         P_range, 
         lw=2.5, 
         color='#1f77b4', 
         label='Новый AD: $200 - 0.5P$',
         )

plt.plot(Y_AS, 
         P_range, 
         lw=2.5, 
         color='#ff7f0e', 
         label='AS: $200 + 0.5(P - 100)$',
         )

plt.scatter(Y_eq, 
            P_eq, 
            s=100, 
            color='red', 
            zorder=5, 
            label=f'Исходное равновесие (Y=190, P=80)'
            )

plt.scatter(Y_eq_shock, 
            P_eq_shock, 
            s=100, 
            color='purple', 
            zorder=5, 
            label=f'Новое равновесие (Y=175, P=50)',
            )

plt.title('Эффект снижения инвестиций (I↓)', fontsize=16, pad=20)
plt.xlabel('Реальный выпуск (Y)', fontsize=12)
plt.ylabel('Уровень цен (P)', fontsize=12)
plt.xticks(np.arange(150, 250, 10))
plt.yticks(np.arange(30, 160, 10))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(frameon=True, loc='upper right', fontsize=10)

plt.annotate('Сокращение инвестиций:\nI уменьшается на 30', 
             xy=(180, 70), 
             xytext=(140, 100),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10,
             color='green')

plt.show()

# %% [markdown]
# ### Анализ графика:
#
# **Сдвиг AD влево:**
#
# Снижение I на 30 единиц привело к параллельному сдвигу кривой AD влево (синяя пунктирная → синяя сплошная).
# Пример: При P=100 → Y_AD = 200 - 0.5*100 = 150 (было 180).
#
# **Новое равновесие (фиолетовая точка):**
#
# * Выпуск упал до Y=175 (дальше от потенциального Y*=200).
#
# * Цены снизились до P=50 (дефляционное давление).
#
# **Эффект «спирали дефляции»:**
# Падение цен может привести к:
#
# * Отсрочке потребления (потребители ждут дальнейшего снижения цен),
#
# * Росту реальной стоимости долгов,
#
# * Сокращению инвестиций и занятости.
#
# ---
#
# ### Интерпретация:
#
# * **Механизм рецессии:**
#
# Инвестиции — ключевой драйвер экономического роста. Их сокращение ведет к:
#
#     1. Падению спроса на товары и услуги,
#
#     2. Снижению доходов бизнеса и домохозяйств,
#
#     3. Дальнейшему сокращению расходов (эффект «снежного кома»).
#
# * **Почему AS не спасает ситуацию?**
#
#     1. Кривая AS остается неизменной, так как шок вызван спросом. Фирмы реагируют на падение AD сокращением производства и цен.
#
# * **Долгосрочные последствия:**
#
#     1. Если дефляция закрепляется, экономика может войти в депрессию. Для восстановления равновесия необходимы:
#
#     2. Стимулирование спроса (например, через монетарную политику),
#
#     3. Восстановление доверия инвесторов.
#
# ---

# %% [markdown]
# ### 5. Увеличение чувствительности предложения (k):
#
# - Изменить k с 0.5 на 1.0.
# - Цель: Понять, как более гибкое предложение влияет на экономику.
#
# ---

# %%
k_new = 1.0

def AS_old(P):
    return 200 + 0.5 * (P - 100)  

def AS_new(P):
    return 200 + k_new * (P - 100)  # Новая AS: 100 + P

P_eq_new = (230 - 100) / (1 + 0.5)  # Решение: 230 - 0.5P = 100 + P → P ≈86.67
Y_eq_new = AD_old(P_eq_new)          # Y = 230 - 0.5*86.67 ≈186.67

plt.figure(figsize=(12, 7))

plt.plot(Y_AD, 
         P_range, 
         lw=2.5, 
         color='#1f77b4', 
         label='AD: $230 - 0.5P$',
         )

plt.plot(Y_AS,
         P_range, 
         lw=2, 
         color='#ff7f0e', 
         linestyle='--', 
         label='Исходная AS (k=0.5)',
         )

plt.plot([AS_new(p) for p in P_range], 
         P_range, 
         lw=2.5, 
         color='#ff7f0e', 
         label='Новая AS (k=1.0): $100 + P$',
         )

plt.scatter(Y_eq, 
            P_eq, 
            s=100, 
            color='red', 
            zorder=5, 
            label=f'Исходное равновесие (Y=190, P=80)'
            )
plt.scatter(Y_eq_new, 
            P_eq_new, 
            s=100, 
            color='purple', 
            zorder=5, 
            label=f'Новое равновесие (Y≈187, P≈87)',
            )

plt.title('Эффект увеличения чувствительности предложения (k↑)', fontsize=16, pad=20)
plt.xlabel('Реальный выпуск (Y)', fontsize=12)
plt.ylabel('Уровень цен (P)', fontsize=12)
plt.xticks(np.arange(150, 250, 10))
plt.yticks(np.arange(50, 160, 10))
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(frameon=True, loc='upper right', fontsize=10)

plt.annotate('Более эластичное предложение:\nk увеличивается до 1.0', 
             xy=(180, 90), 
             xytext=(140, 120),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10,
             color='green')

plt.show()

# %% [markdown]
# ### Анализ графика:
#
# **Изменение наклона AS:**
#
# * Кривая AS стала круче (оранжевая пунктирная → оранжевая сплошная). Это означает, что предложение сильнее реагирует на изменение цен.
# Пример: При P=100 → Y_AS = 100 + 100 = 200 (как и раньше), но при P=120 → Y_AS = 220 (было 210).
#
# **Новое равновесие (фиолетовая точка):**
#
# * Выпуск снизился до Y≈187 (сильнее отклонение от Y*=200).
#
# * Цены выросли до P≈87 (умеренная инфляция).
#
# **Парадокс эластичности:**
#
# Более гибкое предложение (k↑) усиливает реакцию экономики на дисбалансы. В данном случае:
#
# * Фирмы быстрее сокращают выпуск при P < Pe,
#
# * Это углубляет рецессию, несмотря на изначально нейтральный шок.
#
# ---
#
# ### Интерпретация:
#
# * **Механизм влияния k:**
#
# Высокая чувствительность предложения (k=1.0) означает, что:
#
# 1. При P > Pe фирмы активно наращивают выпуск,
#
# 2. При P < Pe резко сокращают производство.
#
#     В данном эксперименте P=87 < Pe=100 → выпуск падает сильнее, чем при k=0.5.
#
# * **Долгосрочные последствия:**
#
#     * Плюсы: Экономика быстрее возвращается к Y* после шоков спроса.
#
#     * Минусы: Краткосрочные колебания Y и P становятся более резкими.
#
# * **Пример: В странах с гибким рынком труда (например, США) AS более эластична, что смягчает последствия рецессий, но усиливает инфляцию при перегреве.**
#
# ---

# %% [markdown]
# ## Выводы по работе с моделью AD-AS
#
# ### 1. Основные закономерности модели
#
# * **Равновесие определяется пересечением AD и AS.**
#
#     * Любые изменения в компонентах AD (C, I, G, X-M) или параметрах AS (Y*, k, Pe) смещают равновесие.
#
#     * Пример: Увеличение G сдвигает AD вправо → рост Y и P (Эксперимент 2).
#
# * **Ценовые и неценовые факторы:**
#
#     * Цена (P) влияет на величину спроса/предложения в краткосрочном периоде.
#
#     * Неценовые факторы (технологии, ожидания, налоги) определяют сдвиги кривых.
#
# ### 2. Роль ожиданий в экономике
#
# * **Инфляционные ожидания (Pe):**
#
#     * Рост Pe сдвигает AS влево → стагфляция (Y↓, P↑) (Эксперимент 3).
#
#     * Ожидания могут стать самореализующимися: если фирмы ждут роста цен, они повышают P, что провоцирует реальную инфляцию.
#
# * **Управление ожиданиями — ключевой инструмент для Центральных банков. Пример:**
#
#     * Якорение инфляционных ожиданий через прозрачную монетарную политику.
#
# ### 3. Эффективность экономической политики
#
# * **Стимулирование спроса (фискальная политика):**
#
#     * Эффективно при наличии свободных ресурсов (Y < Y*).
#
#     * При перегреве экономики (Y > Y*) ведет к инфляции (Эксперимент 2).
#
# * **Шоки предложения:**
#
#     * Требуют мер, направленных на восстановление AS: инвестиции в технологии, снижение налогов для бизнеса (Эксперимент 3).
#
# * **Гибкость предложения (k):**
#
#     * Высокий k усиливает реакцию экономики на шоки → резкие колебания Y и P (Эксперимент 5).
#
#     * Низкий k замедляет адаптацию, но смягчает краткосрочные колебания.
#
# ### 4. Риски и вызовы
#
# * **Дефляционная спираль:**
#
#     * Падение инвестиций (I↓) → снижение AD → дефляция → дальнейшее сокращение расходов (Эксперимент 4).
#
#     * Пример: Великая депрессия 1930-х годов.
#
# * **Стагфляция:**
#
#     * Сочетание стагнации (Y↓) и инфляции (P↑) требует комплексных мер: подавление инфляции + стимулирование предложения (Эксперимент 3).
#
# ### 5. Ограничения модели AD-AS
#
# * **Упрощение реальности:**
#
#     * Не учитывает денежный рынок и ставки процента (влияние монетарной политики).
#
#     * Предполагает статичность ожиданий (Pe фиксирован), хотя в реальности они адаптивны.
#
# * **Краткосрочный фокус:**
#
#     * Долгосрочная кривая AS (LRAS) вертикальна при Y*, но в модели AS обычно рассматривается как восходящая.
#
# ### 6. Практические рекомендации
#
# * **Для борьбы с рецессией:**
#
#     * Стимулировать AD через G↑ или снижение налогов.
#
#     * Поддерживать доверие инвесторов для роста I.
#
# * **Для сдерживания инфляции:**
#
#     * Ужесточение монетарной политики (повышение ставок).
#
#     * Контроль инфляционных ожиданий через коммуникацию.
#
# * **Для устойчивого роста:**
#
#     * Инвестиции в технологии и образование (рост Y*).
#
#     * Гибкость рынков (труда, товаров) для повышения эластичности AS.
#
# ---
#
# ### Итог:
#
# **Модель AD-AS — мощный инструмент для анализа макроэкономической динамики, но ее применение требует учета:**
#
# * Взаимодействия краткосрочных и долгосрочных факторов,
#
# * Роли ожиданий и институтов,
#
# * Ограниченности упрощенных предположений.
# Пример использования: Анализ последствий COVID-19: шок предложения (разрыв цепочек) + шок спроса (падение C и I) → необходимость комбинированной политики.
